# %% [markdown]
# ## <img src="./logo_UTN.svg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 4
# #### Nombre y Apellido
#
# ***
# ## Filtrado

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
#  $$ y(k) = \frac{1}{N} \sum_{i=0}^{N-1} x(k-i)  $$
#
#  Para N = [3; 5]

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante la simulación computacional

# %%
## Inicialización del Notebook del TP4

import numpy as np
from pandas import DataFrame
from IPython.display import HTML
from scipy import signal as sig

# Insertar aquí el código para inicializar tu notebook
########################################################

import matplotlib as mpl
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

import matplotlib.pyplot as plt

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

ww, hh = sig.freqz(np.array([1, 2, 3]), 1)
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='ejemplo')

plt.title('FIR ejemplo')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# $$ h(k) = (-1, 1) $$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# <img src="./comb.png" align="center" width="30%" />
#
#
# Para $N= (2; 4)$ y $b = -1$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> En el archivo *ECG_TP4.mat* encontrará un registro electrocardiográfico (ECG) registrado durante una prueba de esfuerzo, junto con una serie de variables descriptas a continuación. Diseñe y aplique los filtros digitales necesarios para mitigar las siguientes fuentes de contaminación:
# </div>

# %% [markdown]
# ### Archivo *ECG_TP4.mat*
# (variables)
#  - **ecg_lead**: Registro de ECG muestreado a $fs=1$ KHz durante una prueba de esfuerzo
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular
#  - **qrs_detections**: vector con las localizaciones (en # de muestras) donde ocurren los latidos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Revise el concepto de filtro adaptado en [Wikipedia](http://en.wikipedia.org/wiki/Matched_filter), o la bibliografía de la materia (Porat 14.4.9).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> Para la señal de ECG provista junto con este documento, aplique el concepto de *filtro adaptado* y otras técnicas de filtrado digital para diseñar un detector de latidos. Los patrones provistos son:
#
# </div>

# %% [markdown]
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Revise el concepto de filtro adaptado en [Wikipedia](http://en.wikipedia.org/wiki/Matched_filter), o la bibliografía de la materia (Porat 14.4.9).
# </div>

# %%
import scipy.io as sio

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# para listar las variables que hay en el archivo
#io.whosmat('ECG_TP4.mat')
mat_struct = sio.loadmat('./ECG_TP4.mat')

ecg_one_lead = mat_struct['ecg_lead']
ecg_one_lead = ecg_one_lead.flatten(1)
N = len(ecg_one_lead)

hb_1 = mat_struct['heartbeat_pattern1']
hb_1 = hb_1.flatten(1)

plt.figure(1)
plt.plot(ecg_one_lead[5000:12000])

plt.figure(2)
plt.plot(hb_1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   app.launch_new_instance()
# ['__header__', '__version__', '__globals__', 'ecg_lead', 'qrs_pattern1', 'heartbeat_pattern1', 'heartbeat_pattern2']

# %% [markdown]
# a) Explique conceptualmente cómo podría realizar un detector de latidos con la señal resultante del filtro adaptado. Discuta la utilidad y limitaciones de este método.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
#
#    b) Realice la detección de los latidos, comparando las detecciones obtenidas con las que se incluyen en la variable **qrs_detections**

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %%
mat_struct = sio.loadmat('ECG_TP4.mat')

ecg_one_lead = mat_struct['ecg_lead']
ecg_one_lead = ecg_one_lead.flatten()
N = len(ecg_one_lead)

qrs_detections = mat_struct['qrs_detections']
qrs_detections = qrs_detections.flatten()


all_heartbeats = np.hstack([ ecg_one_lead[ (qrs_detections[ii] - 250):(qrs_detections[ii] + 350) ]  for ii in range(len(qrs_detections)) ])
all_heartbeats=sig.detrend(all_heartbeats,axis=0)

A = np.abs(np.fft.fft(all_heartbeats, axis=0))


plt.plot( ff[:300], np.cumsum(A[:300,:]) / np.broadcast_to(np.sum(A[:300,:], axis=0), (300,A.shape[1]) ) )
plt.plot( ff[:300], np.cumsum(A[:300,:], axis=0) / np.broadcast_to(np.sum(A[:300,:], axis=0), (300,A.shape[1]) ) )
plt.plot( ff[:300], A[:300,:] )
plt.plot( ff[:300], A[:300,:] )
plt.plot( ff[:300], A[:300,:] / np.broadcast_to(np.max(A[:300,:], axis=0), (300,A.shape[1]) ) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a1d68a14dda> in <module>()
# ----> 1 mat_struct = sio.loadmat('ECG_TP4.mat')
#       2
#       3 ecg_one_lead = mat_struct['ecg_lead']
#       4 ecg_one_lead = ecg_one_lead.flatten()
#       5 N = len(ecg_one_lead)
#
# NameError: name 'sio' is not defined

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.c)</b> Repita a) incrementando la frecuencia de $x_1$ para $\Omega_1 = \frac{\pi}{2} + d_1·\frac{2\pi}{N}$ para valores de $d_1 = (0,01; 0.25; 0.5)$. Aumente la amplitud de $a_2$ hasta que se evidencie sobre el leakage y construya una tabla con dicho valor para las 3 situaciones correspondientes a desintonías leve, moderada y máxima.
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################



#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   '', # <-- acá debería haber numeritos :)
                   '', # <-- acá debería haber numeritos :)
                   '' # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$a_2$ (dB)'],
               index=[  
                        'leve',
                        'moderada',
                        'máxima',
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$a_2$ (dB)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>leve</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>moderada</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>máxima</th>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.d)</b> Evalúe el efecto de utilizar las ventanas implementadas en 1). Complete la tabla comparativa con respecto a la ventana rectangular, respecto a las mediciones $a^0_2$ realizada en 2.b); y $a^1_2$ en 2.c) para el caso de desintonía máxima.
# </div>

# %% [markdown]
# Grafique $\lvert X_w(\Omega) \rvert = \lvert \mathcal{F}\{ x(k) · w(k) \} \rvert $ para las 4 ventanas de 1).

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''] # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$a^0_2$ (dB)','$a^1_2$ (dB)'],
               index=[  
                        'Rectangular',
                        'Bartlett',
                        'Hann',
                        'Blackman',
                        'Flat-top'
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$a^0_2$ (dB)</th>
#       <th>$a^1_2$ (dB)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Rectangular</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Bartlett</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Hann</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Blackman</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Flat-top</th>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.e)</b> Para las ventanas analizadas en 1), decida cuál sería la más apropiada en el caso que, <b>sin afectar otro parámetro</b>, $\Omega_2$ pudiera acercarse libremente a $\Omega_1 = \frac{\pi}{2} + 0.5·\frac{2\pi}{N}$. Complete la siguiente tabla con la distancia mínima, $\Omega_0, $ a la que se puede distinguir $x_2$ en $\lvert X_w(\Omega) \rvert$.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   '', # <-- acá debería haber numeritos :)
                   '', # <-- acá debería haber numeritos :)
                   '', # <-- acá debería haber numeritos :)
                   '', # <-- acá debería haber numeritos :)
                   '' # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$\Omega_0$ (#)'],
               index=[  
                        'Rectangular',
                        'Bartlett',
                        'Hann',
                        'Blackman',
                        'Flat-top'
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$\Omega_0$ (#)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Rectangular</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Bartlett</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Hann</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Blackman</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Flat-top</th>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Genere la siguiente señal
#
# </div>

# %% [markdown]
#   $  x(k) = a_0·\mathop{sen}(\Omega_1·k)$
#
#
# siendo
#
#   $a_0 = 2$
#
#   $\Omega_1 = \Omega_0 + f_r·\frac{2\pi}{N} $
#
#   $\Omega_0 = \frac{\pi}{2} $
#
# y la variable aleatoria definida por
#
#   $f_r \sim \mathcal{U}(-2, \, 2) $
#
# Considere 200 realizaciones para cada experimento requerido en los siguiente incisos.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.a)</b> Calcule experimentalmente el sesgo y la varianza del siguiente estimador:
# </div>

# %% [markdown]
#
#   $ \hat{a_0} = \lvert X^i_w(\Omega_0) \rvert$
#
# siendo
#
#   $\lvert X^i_w(\Omega) \rvert = \lvert \mathcal{F}\{ x(k) · w_i(k) \} \rvert $
#
# para la *i*-ésima ventana de las 5 utilizadas en el punto 2).
#
# El sesgo y la varianza se definen para este caso como
#
#   $ s_a = \mathop{E}\{ \hat{a_0}\} - a_0  $
#
#   $ v_a = \mathop{var} \{ \hat{a_0} \} = \mathop{E}\{ ( \hat{a_0} - \mathop{E} \{ \hat{a_0} \} )^2 \} $
#
# y pueden aproximarse cuando consideramos los valores esperados como las medias muestrales ($a=a_0$ para simplificar la notación)
#
#   $ \mathop{E}\{ \hat{a_0}\}  = \hat{\mu_a} =  \frac{1}{M} \sum^{M-1}_{j=0} \hat{a_{j}} $
#
#   $ s_a = \hat{\mu_a} - a  $
#
#   $ v_a = \frac{1}{M} \sum^{M-1}_{j=0} (\hat{a_{j}} - \hat{\mu_a})^2 $

# %% [markdown]
# Grafique los histogramas para  $\lvert X^i_w(\Omega_0) \rvert$.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Cuide que todos los gráficos tengan <b>el mismo rango de valores en X</b> para facilitar la comparación.
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$s_a$', '$v_a$'],
               index=[  
                        'Rectangular',
                        'Bartlett',
                        'Hann',
                        'Blackman',
                        'Flat-top'
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$s_a$</th>
#       <th>$v_a$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Rectangular</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Bartlett</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Hann</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Blackman</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Flat-top</th>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.b)</b> Repita a) para el siguiente estimador:
# </div>

# %% [markdown]
#
#   $ \hat{a_1} = \sqrt{\frac{1}{5}·\sum_{j=a}^{b} \lvert X^i_w(j) \rvert ^2} $
#
# siendo $ a = \Omega_0 - 2·\frac{2\pi}{N} $ y $ b = \Omega_0 + 2·\frac{2\pi}{N} $
#
# para la *i*-ésima ventana de las 5 utilizadas en el punto 2).

# %% [markdown]
# Grafique los histogramas para  $\lvert X^i_w(\Omega_0) \rvert$.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Cuide que todos los gráficos tengan <b>el mismo rango de valores en X</b> para facilitar la comparación.
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                   ['', ''], # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$s_a$', '$v_a$'],
               index=[  
                        'Rectangular',
                        'Bartlett',
                        'Hann',
                        'Blackman',
                        'Flat-top'
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$s_a$</th>
#       <th>$v_a$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Rectangular</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Bartlett</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Hann</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Blackman</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Flat-top</th>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
